# %%
cd url2ipynb
# Out:
# d:\Documents\python\url2ipynb

# %%
pwd
# Out:
# 'd:\\Documents\\python'

# %%
import url2ipynb

# %%
url = 'https://plot.ly/python/pie-charts/'
outfile='bar_chart.ipynb'
url2ipynb.url2ipynb(url,outfile)
